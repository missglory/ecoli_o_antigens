# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
df = pd.read_csv("gedlib_edit_dists.csv", index_col=0)
dfn = df.to_numpy()
dfn = dfn[np.triu_indices(dfn.shape[0], k=1)]
# dfn = np.triu(dfn, k=1).flatten()
# dfn

plt.hist(dfn, bins=20)
plt.show()
